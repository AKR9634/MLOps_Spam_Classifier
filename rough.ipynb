# %%
from src.utils import read_yaml_file

# %%
schema = read_yaml_file("config/schema.yaml")

# %%
schema
# Out:
# {'columns': {'v1': 'category',
#   'v2': 'str',
#   'Unnamed: 2': 'int',
#   'Unnamed: 3': 'int',
#   'Unnamed: 4': 'int'},
#  'categorical_columns': ['v1'],
#  'rename_columns': {'v1': 'label', 'v2': 'message'},
#  'drop_columns': ['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],
#  'num_features': ['v1', 'v2']}

# %%
schema["rename_columns"]
# Out:
# {'v1': 'label', 'v2': 'message'}

# %%
schema["drop_columns"]
# Out:
# ['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4']

# %%
for col in schema["drop_columns"]:
    print(col)
# Out:
# Unnamed: 2
# Unnamed: 3
# Unnamed: 4

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Dell\Desktop\Machine_Learning and Operations\MLOps_Spam_Classifier\artifact\03_05_2026_22_24_43\data_ingestion\ingested\test.csv")

# %%
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Cbe is really good nowadays:)lot of shop and s...        NaN
# 1      ham                     What year. And how many miles.        NaN
# 2      ham  sir, you will receive the account no another 1...        NaN
# 3      ham  either way works for me. I am  &lt;#&gt;  year...        NaN
# 4      ham  In fact when do you leave? I think addie goes ...        NaN
# ...    ...                                                ...        ...
# 2781   ham                        So dont use hook up any how        NaN
# 2782  spam  FreeMsg Hey U, i just got 1 of these video/pic...        NaN
# 2783   ham                           I'm at home. Please call        NaN
# 2784   ham                Sir Goodmorning, Once free call me.        NaN
# 2785   ham  Future is not what we planned for tomorrow.......        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
y = df.iloc[:, 0]

# %%
y
# Out:
# 0        ham
# 1        ham
# 2        ham
# 3        ham
# 4        ham
#         ...
# 2781     ham
# 2782    spam
# 2783     ham
# 2784     ham
# 2785     ham
# Name: v1, Length: 2786, dtype: object

# %%
y = y.map({"ham" : 0, "spam" : 1})

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2781    0
# 2782    1
# 2783    0
# 2784    0
# 2785    0
# Name: v1, Length: 2786, dtype: int64
